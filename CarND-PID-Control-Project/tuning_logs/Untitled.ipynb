# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/wwymak/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
a = pd.read_csv('pid-p=0.050000Ki=0.000000Kd=0.000000')
b = pd.read_csv('pid-p=0.100000Ki=0.000000Kd=0.000000')
c = pd.read_csv('pid-p=0.200000Ki=0.000000Kd=0.000000')

# %%
plt.figure(figsize = (8,6))
plt.plot(a['cte'])
plt.plot(b['cte'])
plt.plot(c['cte'])

plt.legend(['pid = 0.05,0,0', 'pid = 0.10,0,0', 'pid = 0.20,0,0'], loc='upper left')

plt.show()

# %%
plt.plot(b['cte'])
